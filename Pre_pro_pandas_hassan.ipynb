# %%
import pandas as pd

# %%
# Create

data = {
    "name": ['a','b','c'],
    "age" : [20,30,40]
}

# %%
df = pd.DataFrame(data)

# %%
df2 = pd.read_csv('./data.csv')
df2
# Out:
#       Name  Age  Salary
# 0      ali   20    1000
# 1   hassan   30    2000
# 2    zahra   40    3000
# 3  hussein   30    3000
# 4     jiji   38    2000
# 5     nono   19    1000
# 6     koko   30    3000
# 7     jaja   20    1090

# %%
df2.head()
# Out:
#       Name  Age  Salary
# 0      ali   20    1000
# 1   hassan   30    2000
# 2    zahra   40    3000
# 3  hussein   30    3000
# 4     jiji   38    2000

# %%
df2.describe()
# Out:
#              Age       Salary
# count   8.000000     8.000000
# mean   28.375000  2011.250000
# std     8.140507   912.382086
# min    19.000000  1000.000000
# 25%    20.000000  1067.500000
# 50%    30.000000  2000.000000
# 75%    32.000000  3000.000000
# max    40.000000  3000.000000

# %%
df2
# Out:
#       Name  Age  Salary
# 0      ali   20    1000
# 1   hassan   30    2000
# 2    zahra   40    3000
# 3  hussein   30    3000
# 4     jiji   38    2000
# 5     nono   19    1000
# 6     koko   30    3000
# 7     jaja   20    1090

# %%
df2
# Out:
#       Name  Age  Salary
# 0      ali   20    1000
# 1   hassan   30    2000
# 2    zahra   40    3000
# 3  hussein   30    3000
# 4     jiji   38    2000
# 5     nono   19    1000
# 6     koko   30    3000
# 7     jaja   20    1090

# %%
filterd_df2 = df2[df2["Salary"]>2000 ]
filterd_df2
# Out:
#       Name  Age  Salary
# 2    zahra   40    3000
# 3  hussein   30    3000
# 6     koko   30    3000

# %%
# Sort

sorted_df = df2.sort_values("Age", ascending=False)

# %%
sorted_df
# Out:
#       Name  Age  Salary
# 5     nono   19    1000
# 0      ali   20    1000
# 7     jaja   20    1090
# 1   hassan   30    2000
# 3  hussein   30    3000
# 6     koko   30    3000
# 4     jiji   38    2000
# 2    zahra   40    3000

# %%
sorted_df
# Out:
#       Name  Age  Salary
# 2    zahra   40    3000
# 4     jiji   38    2000
# 1   hassan   30    2000
# 3  hussein   30    3000
# 6     koko   30    3000
# 0      ali   20    1000
# 7     jaja   20    1090
# 5     nono   19    1000

# %%
df2
# Out:
#       Name  Age  Salary
# 0      ali   20    1000
# 1   hassan   30    2000
# 2    zahra   40    3000
# 3  hussein   30    3000
# 4     jiji   38    2000
# 5     nono   19    1000
# 6     koko   30    3000
# 7     jaja   20    1090

# %%
# subset

subset_df = df2.loc[2:6,["Name",'Age']]

# %%
subset_df
# Out:
#       Name  Age
# 2    zahra   40
# 3  hussein   30
# 4     jiji   38
# 5     nono   19
# 6     koko   30

# %%
# groupby

grouped_df = df2.groupby("Age")
grouped_df

# %%
grouped_df.count()
# Out:
#      Name  Salary
# Age
# 19      1       1
# 20      2       2
# 30      3       3
# 38      1       1
# 40      1       1

# %%
df2["test"]=[1,2,3,4,5,6,7,8]

# %%
df2
# Out:
#       Name  Age  Salary  test
# 0      ali   20    1000     1
# 1   hassan   30    2000     2
# 2    zahra   40    3000     3
# 3  hussein   30    3000     4
# 4     jiji   38    2000     5
# 5     nono   19    1000     6
# 6     koko   30    3000     7
# 7     jaja   20    1090     8

# %%
new_df = df2.drop(0, axis=0)

# %%
new_df
# Out:
#       Name  Age  Salary
# 0      ali   20    1000
# 1   hassan   30    2000
# 2    zahra   40    3000
# 3  hussein   30    3000
# 4     jiji   38    2000
# 5     nono   19    1000
# 6     koko   30    3000
# 7     jaja   20    1090

# %%
new_df
# Out:
#       Name  Age  Salary  test
# 1   hassan   30    2000     2
# 2    zahra   40    3000     3
# 3  hussein   30    3000     4
# 4     jiji   38    2000     5
# 5     nono   19    1000     6
# 6     koko   30    3000     7
# 7     jaja   20    1090     8

# %%
len(new_df)
# Out:
# 7

# %%
new_df
# Out:
#       Name  Age  Salary  test
# 1   hassan   30    2000     2
# 2    zahra   40    3000     3
# 3  hussein   30    3000     4
# 4     jiji   38    2000     5
# 5     nono   19    1000     6
# 6     koko   30    3000     7
# 7     jaja   20    1090     8

# %%
new_df.loc[len(new_df)]={"Name":"alibaba","Age":22}

# %%
new_df.drop("test", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 new_df.drop("test", axis=1, inplace=True)
#
# File c:\Users\yasin\Documents\Programming SandBox\learnig_venv\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
# ...

# %%
new_df
# Out:
#       Name  Age  Salary
# 1   hassan   30  2000.0
# 2    zahra   40  3000.0
# 3  hussein   30  3000.0
# 4     jiji   38  2000.0
# 5     nono   19  1000.0
# 6     koko   30  3000.0
# 7  alibaba   22     NaN

# %%
new_df.isna()
# Out:
#     Name    Age  Salary
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False    True

# %%
dfz = new_df.fillna(0)
dfz
# Out:
#       Name  Age  Salary
# 1   hassan   30  2000.0
# 2    zahra   40  3000.0
# 3  hussein   30  3000.0
# 4     jiji   38  2000.0
# 5     nono   19  1000.0
# 6     koko   30  3000.0
# 7  alibaba   22     0.0

# %%
dfx = new_df.dropna()
dfx
# Out:
#       Name  Age  Salary
# 1   hassan   30  2000.0
# 2    zahra   40  3000.0
# 3  hussein   30  3000.0
# 4     jiji   38  2000.0
# 5     nono   19  1000.0
# 6     koko   30  3000.0

# %%
dfz.to_csv('newdata.csv')
